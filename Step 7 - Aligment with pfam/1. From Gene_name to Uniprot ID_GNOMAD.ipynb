# %%
import pandas as pd

# %%
# Open data into a DataFrame using Pandas
# The original file has no header
df = pd.read_csv("TM_gnomad_nonPatho_missense.csv", sep=",", header=0)
df = df [["Gene(s)", "position", "initial_aa", "final_aa", "Transmembrane_Regions_new", "Pfam_code"]]
df
# Out:
#        Gene(s)  position initial_aa final_aa Transmembrane_Regions_new  \
# 0      TNFRSF4     229.0        Gly      Gly          [['215', '235']]
# 1      TNFRSF4     228.0        Leu      Leu          [['215', '235']]
# 2      TNFRSF4     226.0        Gly      Ala          [['215', '235']]
# 3      TNFRSF4     223.0        Leu      Pro          [['215', '235']]
# 4      TNFRSF4     223.0        Leu      Val          [['215', '235']]
# ...        ...       ...        ...      ...                       ...
# 45968   PLXNA3    1238.0        Val      Val        [['1221', '1241']]
# 45969   PLXNA3    1241.0        Ala      Val        [['1221', '1241']]
# 45970   PLXNA3    1241.0        Ala      Ala        [['1221', '1241']]
# 45971    CLIC2      41.0        Trp      Ser            [['32', '52']]
# 45972    CLIC2      40.0        Leu      Leu            [['32', '52']]
#
#                                              Pfam_code
# 0                                              PF00020
# 1                                              PF00020
# 2                                              PF00020
# 3                                              PF00020
# 4                                              PF00020
# ...                                                ...
# 45968  PF08337_PF01437_PF01403_PF01833_PF18020_PF17960
# 45969  PF08337_PF01437_PF01403_PF01833_PF18020_PF17960
# 45970  PF08337_PF01437_PF01403_PF01833_PF18020_PF17960
# 45971                                          PF13409
# 45972                                          PF13409
#
# [45973 rows x 6 columns]

# %%
# Function imported from: https://chem-workflows.com/articles/2019/10/29/retrieve-uniprot-data-using-python/
# pip install beautifulsoup4
import urllib
from bs4 import BeautifulSoup

def get_uniprot (query='',query_type='ACC'):
    #query_type must be: "PDB_ID" or "ACC"
    url = 'https://www.uniprot.org/uploadlists/' #This is the webser to retrieve the Uniprot data
    params = {
    'from':query_type,
    'to':'ACC',
    'format':'txt',
    'query':query,
    'taxon':'9606'
    }

    data = urllib.parse.urlencode(params)
    data = data.encode('ascii')
    request = urllib.request.Request(url, data)
    with urllib.request.urlopen(request) as response:
        res = response.read()
        page=BeautifulSoup(res).get_text()
        page=page.splitlines()
    return page

# %%
GN = []
for UniProtKB_GN in df['Gene(s)']:
    GN.append(UniProtKB_GN)
res = []
[res.append(x) for x in GN if x not in res]
print(res)
# Out:
# ['TNFRSF4', 'B3GALT6', 'MXRA8', 'ATAD3A', 'TMEM240', 'GPR153', 'SLC45A1', 'UBIAD1', 'MFN2', 'EPHA2', 'ATP13A2', 'UBR4', 'EMC1', 'PINK1', 'DDOST', 'ECE1', 'EPHB2', 'SLC30A2', 'PIGV', 'SLC9A1', 'TMEM222', 'PTPRU', 'ADGRB2', 'GJB4', 'GJB3', 'GJA4', 'CSF3R', 'ZMPSTE24', 'KCNQ4', 'CLDN19', 'SLC2A1', 'TIE1', 'MPL', 'ELOVL1', 'ST3GAL3', 'SLC6A9', 'DHCR24', 'BSND', 'TACSTD2', 'ALG6', 'ROR1', 'LEPR', 'SLC35D1', 'PIGK', 'HS2ST1', 'ABCA4', 'SLC35A3', 'SLC30A7', 'SLC25A24', 'CLCC1', 'CELSR2', 'SLC6A17', 'KCNA2', 'DRAM2', 'KCND3', 'SLC16A1', 'LRIG2', 'VANGL1', 'ATP1A1', 'HSD3B2', 'NOTCH2', 'GJA5', 'GJA8', 'IL6R', 'CHRNB2', 'KCNN3', 'DPM3', 'SEMA4A', 'NTRK1', 'KIRREL1', 'CADM3', 'PIGM', 'KCNJ10', 'ATP1A2', 'NCSTN', 'NECTIN4', 'MPZ', 'SDHC', 'ATF6', 'DDR2', 'ILDR2', 'CD247', 'GPR161', 'SLC19A2', 'FMO3', 'FASLG', 'ASTN1', 'TOR1AIP1', 'XPR1', 'MR1', 'CACNA1E', 'KCNT2', 'CRB1', 'CACNA1S', 'SYT2', 'NFASC', 'SLC41A1', 'CR2', 'CD46', 'PLXNA2', 'SYT14', 'HHAT', 'KCNH1', 'FLVCR1', 'USH2A', 'SLC30A10', 'DEGS1', 'LBR', 'TMEM63A', 'PSEN2', 'COQ8A', 'GJC2', 'GALNT2', 'ARV1', 'B3GALNT2', 'RYR2', 'CHRM3', 'TPO', 'ADAM17', 'KCNF1', 'SELENOI', 'OTOF', 'KCNK3', 'SLC5A6', 'MPV17', 'ALK', 'SRD5A2', 'ABCG8', 'SLC3A1', 'PIGF', 'EPCAM', 'FSHR', 'PEX13', 'SLC1A4', 'PROKR1', 'ANTXR1', 'DYSF', 'MOGS', 'HTRA2', 'GGCX', 'ST3GAL5', 'REEP1', 'CD8A', 'EIF2AK3', 'LMAN2L', 'CNNM4', 'CNGA3', 'SLC5A7', 'MERTK', 'TMEM87B', 'SMPD4', 'LCT', 'ACVR1', 'ITGB6', 'SCN3A', 'SCN2A', 'GALNT3', 'SCN1A', 'SCN9A', 'ABCB11', 'LRP2', 'SLC25A12', 'ITGA6', 'CHRNA1', 'ATP5MC3', 'SLC40A1', 'PGAP1', 'NDUFB3', 'TMEM237', 'BMPR2', 'CTLA4', 'PTH2R', 'UNC80', 'ERBB4', 'ABCA12', 'CXCR2', 'CXCR1', 'BCS1L', 'ABCB6', 'EPHA4', 'SLC19A3', 'ECEL1', 'CHRND', 'CHRNG', 'ACKR3', 'GAL3ST2', 'ITPR1', 'GRM7', 'JAGN1', 'ATP2B2', 'SLC6A1', 'TMEM43', 'SLC6A6', 'TGFBR2', 'ACVR2B', 'SCN5A', 'SCN10A', 'SCN11A', 'CX3CR1', 'SLC25A38', 'POMGNT2', 'ANO10', 'TMIE', 'PTH1R', 'CELSR3', 'SLC25A20', 'P4HTM', 'USP19', 'MST1R', 'CACNA2D2', 'TLR9', 'RFT1', 'CACNA1D', 'IL17RD', 'SLC25A26', 'ROBO1', 'IMPG2', 'NECTIN3', 'ILDR1', 'CASR', 'ADCY5', 'PLXNA1', 'SEC61A1', 'GP9', 'RHO', 'ATP2C1', 'SLCO2A1', 'AGTR1', 'RNF13', 'MME', 'SLC33A1', 'SI', 'SLC7A14', 'SLC2A2', 'GHSR', 'DNAJC19', 'ALG3', 'CLCN2', 'CLDN16', 'OPA1', 'ATP13A3', 'NRROS', 'PIGG', 'FGFR3', 'LETM1', 'EVC2', 'SLC2A9', 'PROM1', 'TAPT1', 'SLC34A2', 'TLR1', 'SLC30A9', 'GABRA2', 'GABRB1', 'CORIN', 'SGCB', 'PDGFRA', 'KIT', 'KDR', 'TMEM165', 'TECRL', 'EPHA5', 'GNRHR', 'SLC4A4', 'SCARB2', 'FRAS1', 'ANTXR2', 'SCD5', 'COQ2', 'PKD2', 'GRID2', 'BMPR1B', 'SLC39A8', 'TACR3', 'CYP2U1', 'COL25A1', 'LRIT3', 'EGF', 'ZGRF1', 'TRPC3', 'KIAA1109', 'FAT4', 'MFSD8', 'CLGN', 'SLC10A7', 'EDNRA', 'LRBA', 'LRAT', 'ASIC5', 'GLRB', 'GRIA2', 'MSMO1', 'CLCN3', 'TENM3', 'SLC25A4', 'CYP4V2', 'FAT1', 'SLC9A3', 'SLC6A19', 'SLC6A3', 'ANKH', 'NPR3', 'PRLR', 'IL7R', 'LMBRD2', 'SLC1A3', 'CPLANE1', 'LIFR', 'OSMR', 'GHR', 'NNT', 'HCN1', 'IL31RA', 'IL6ST', 'OCLN', 'ADGRV1', 'SLC25A46', 'KCNN2', 'MEGF10', 'SLC12A2', 'SLC22A5', 'UQCRQ', 'REEP2', 'STING1', 'PCDH1', 'SLC26A2', 'PDGFRB', 'NDST1', 'GLRA1', 'GRIA1', 'SGCD', 'NIPAL4', 'GABRB2', 'GABRA1', 'GABRG2', 'ERGIC1', 'FGFR4', 'SLC34A1', 'B4GALT7', 'GRM6', 'FLT4', 'GCNT2', 'HFE', 'MOG', 'TNF', 'ABHD16A', 'SLC44A4', 'TAP1', 'SLC39A7', 'LEMD2', 'LHFPL5', 'SLC26A8', 'KCNK17', 'TREM2', 'PRPH2', 'RHAG', 'PKHD1', 'ELOVL5', 'ADGRB3', 'KCNQ5', 'SLC17A5', 'ELOVL4', 'SNX14', 'SLC35A1', 'GRIK2', 'BVES', 'SEC63', 'DSE', 'ROS1', 'NUS1', 'GJA1', 'TRDN', 'ENPP1', 'STX7', 'PERP', 'ADGRG6', 'PEX3', 'GRM1', 'IYD', 'SYNE1', 'PNLDC1', 'IGF2R', 'MPC1', 'ERMARD', 'INTS1', 'LFNG', 'KDELR2', 'TMEM106B', 'AQP1', 'GHRHR', 'PKD1L1', 'EGFR', 'DNAJC30', 'STX1A', 'POR', 'ZP3', 'CD36', 'ABCB4', 'ABCB1', 'SLC25A13', 'CYP3A4', 'TFR2', 'EPHB4', 'SLC26A5', 'SLC26A4', 'SLC26A3', 'NRCAM', 'MET', 'CFTR', 'KCND2', 'TSPAN12', 'SMO', 'MEST', 'ATP6V0A4', 'KIAA1549', 'TBXAS1', 'TRPV6', 'CLCN1', 'CNTNAP2', 'KCNH2', 'SLC4A2', 'DPP6', 'CLN8', 'TUSC3', 'MSR1', 'CSGALNACT1', 'SLC39A14', 'CHRNA2', 'EXTL3', 'ERLIN2 ...

# %%
gene_name = []
for a in res:
    y=get_uniprot(query=a ,query_type='GENENAME')
    for line in y:
        if line.startswith('ID   '):
            gene_name.append(a+':'+line)
#print(gene_name)

# %%
df_gene_name =  pd.DataFrame (gene_name, columns = ['GN'])
df_gene_name
# Out:
#                                                      GN
# 0     TNFRSF4:ID   TNR4_HUMAN              Reviewed;...
# 1     TNFRSF4:ID   A0A024R0B2_HUMAN        Unreviewe...
# 2     B3GALT6:ID   B3GT6_HUMAN             Reviewed;...
# 3     B3GALT6:ID   Q499Z2_HUMAN            Unreviewe...
# 4     MXRA8:ID   MXRA8_HUMAN             Reviewed;  ...
# ...                                                 ...
# 7407  PLXNA3:ID   PLXA3_HUMAN             Reviewed; ...
# 7408  PLXNA3:ID   L8ECH0_HUMAN            Unreviewed...
# 7409  CLIC2:ID   CLIC2_HUMAN             Reviewed;  ...
# 7410  CLIC2:ID   A6PVS0_HUMAN            Unreviewed;...
# 7411  CLIC2:ID   Q86YM0_HUMAN            Unreviewed;...
#
# [7412 rows x 1 columns]

# %%
df_gene_name[['GN', 'ID']] = df_gene_name['GN'].str.split(':', 1, expand=True)
df_gene_name
# Out:
#            GN                                                 ID
# 0     TNFRSF4  ID   TNR4_HUMAN              Reviewed;        ...
# 1     TNFRSF4  ID   A0A024R0B2_HUMAN        Unreviewed;      ...
# 2     B3GALT6  ID   B3GT6_HUMAN             Reviewed;        ...
# 3     B3GALT6  ID   Q499Z2_HUMAN            Unreviewed;      ...
# 4       MXRA8  ID   MXRA8_HUMAN             Reviewed;        ...
# ...       ...                                                ...
# 7407   PLXNA3  ID   PLXA3_HUMAN             Reviewed;        ...
# 7408   PLXNA3  ID   L8ECH0_HUMAN            Unreviewed;      ...
# 7409    CLIC2  ID   CLIC2_HUMAN             Reviewed;        ...
# 7410    CLIC2  ID   A6PVS0_HUMAN            Unreviewed;      ...
# 7411    CLIC2  ID   Q86YM0_HUMAN            Unreviewed;      ...
#
# [7412 rows x 2 columns]

# %%
df_gene_name['ID'] = df_gene_name['ID'].str.split(' ').str[3]
df_gene_name
# Out:
#            GN                ID
# 0     TNFRSF4        TNR4_HUMAN
# 1     TNFRSF4  A0A024R0B2_HUMAN
# 2     B3GALT6       B3GT6_HUMAN
# 3     B3GALT6      Q499Z2_HUMAN
# 4       MXRA8       MXRA8_HUMAN
# ...       ...               ...
# 7407   PLXNA3       PLXA3_HUMAN
# 7408   PLXNA3      L8ECH0_HUMAN
# 7409    CLIC2       CLIC2_HUMAN
# 7410    CLIC2      A6PVS0_HUMAN
# 7411    CLIC2      Q86YM0_HUMAN
#
# [7412 rows x 2 columns]

# %%
df_gene_name = df_gene_name.drop_duplicates()
df_gene_name
# Out:
#            GN                ID
# 0     TNFRSF4        TNR4_HUMAN
# 1     TNFRSF4  A0A024R0B2_HUMAN
# 2     B3GALT6       B3GT6_HUMAN
# 3     B3GALT6      Q499Z2_HUMAN
# 4       MXRA8       MXRA8_HUMAN
# ...       ...               ...
# 7407   PLXNA3       PLXA3_HUMAN
# 7408   PLXNA3      L8ECH0_HUMAN
# 7409    CLIC2       CLIC2_HUMAN
# 7410    CLIC2      A6PVS0_HUMAN
# 7411    CLIC2      Q86YM0_HUMAN
#
# [7412 rows x 2 columns]

# %%
df_gene_name['ID'] = df_gene_name.groupby(['GN'])['ID'].transform(lambda x : ' '.join(x))
df_gene_name = df_gene_name.drop_duplicates()
df_gene_name
# Out:
#            GN                                                 ID
# 0     TNFRSF4                        TNR4_HUMAN A0A024R0B2_HUMAN
# 2     B3GALT6                           B3GT6_HUMAN Q499Z2_HUMAN
# 4       MXRA8                       MXRA8_HUMAN A0A024R0A0_HUMAN
# 6      ATAD3A              ATD3A_HUMAN H0Y2W2_HUMAN Q5SV16_HUMAN
# 9     TMEM240                       TM240_HUMAN A0A096LNN7_HUMAN
# ...       ...                                                ...
# 7387   OPN1MW  OPSG_HUMAN B2RU31_HUMAN B7ZLG5_HUMAN H0Y642_HUMAN
# 7391      EMD  EMD_HUMAN A0A804HIG7_HUMAN A0A804HIV7_HUMAN A0...
# 7397  ATP6AP1  VAS1_HUMAN A0A0C4DGX8_HUMAN A0A7I2V2G3_HUMAN A...
# 7407   PLXNA3                           PLXA3_HUMAN L8ECH0_HUMAN
# 7409    CLIC2              CLIC2_HUMAN A6PVS0_HUMAN Q86YM0_HUMAN
#
# [983 rows x 2 columns]

# %%
df_gene_name.to_csv('TM_gnomad+GN_nonPatho_missense.txt', header=True, index=False, sep='\t', mode='a')

# %%
df_aux = pd.read_csv("TM_gnomad+GN_nonPatho_missense.txt", sep="\t", header=0)
df_aux = df_aux.rename(columns={"GN":"Gene(s)"})
df_aux
# Out:
#      Gene(s)                                                 ID
# 0    TNFRSF4                        TNR4_HUMAN A0A024R0B2_HUMAN
# 1    B3GALT6                           B3GT6_HUMAN Q499Z2_HUMAN
# 2      MXRA8                       MXRA8_HUMAN A0A024R0A0_HUMAN
# 3     ATAD3A              ATD3A_HUMAN H0Y2W2_HUMAN Q5SV16_HUMAN
# 4    TMEM240                       TM240_HUMAN A0A096LNN7_HUMAN
# ..       ...                                                ...
# 978   OPN1MW  OPSG_HUMAN B2RU31_HUMAN B7ZLG5_HUMAN H0Y642_HUMAN
# 979      EMD  EMD_HUMAN A0A804HIG7_HUMAN A0A804HIV7_HUMAN A0...
# 980  ATP6AP1  VAS1_HUMAN A0A0C4DGX8_HUMAN A0A7I2V2G3_HUMAN A...
# 981   PLXNA3                           PLXA3_HUMAN L8ECH0_HUMAN
# 982    CLIC2              CLIC2_HUMAN A6PVS0_HUMAN Q86YM0_HUMAN
#
# [983 rows x 2 columns]

# %%
result = df.merge(df_aux, on='Gene(s)', how='outer')
result
# Out:
#        Gene(s)  position initial_aa final_aa Transmembrane_Regions_new  \
# 0      TNFRSF4     229.0        Gly      Gly          [['215', '235']]
# 1      TNFRSF4     228.0        Leu      Leu          [['215', '235']]
# 2      TNFRSF4     226.0        Gly      Ala          [['215', '235']]
# 3      TNFRSF4     223.0        Leu      Pro          [['215', '235']]
# 4      TNFRSF4     223.0        Leu      Val          [['215', '235']]
# ...        ...       ...        ...      ...                       ...
# 45968   PLXNA3    1238.0        Val      Val        [['1221', '1241']]
# 45969   PLXNA3    1241.0        Ala      Val        [['1221', '1241']]
# 45970   PLXNA3    1241.0        Ala      Ala        [['1221', '1241']]
# 45971    CLIC2      41.0        Trp      Ser            [['32', '52']]
# 45972    CLIC2      40.0        Leu      Leu            [['32', '52']]
#
#                                              Pfam_code  \
# 0                                              PF00020
# 1                                              PF00020
# 2                                              PF00020
# 3                                              PF00020
# 4                                              PF00020
# ...                                                ...
# 45968  PF08337_PF01437_PF01403_PF01833_PF18020_PF17960
# 45969  PF08337_PF01437_PF01403_PF01833_PF18020_PF17960
# 45970  PF08337_PF01437_PF01403_PF01833_PF18020_PF17960
# 45971                                          PF13409
# 45972                                          PF13409
#
#                                           ID
# 0                TNR4_HUMAN A0A024R0B2_HUMAN
# 1                TNR4_HUMAN A0A024R0B2_HUMAN
# 2                TNR4_HUMAN A0A024R0B2_HUMAN
# 3                TNR4_HUMAN A0A024R0B2_HUMAN
# 4                TNR4_HUMAN A0A024R0B2_HUMAN
# ...                                      ...
# 45968               PLXA3_HUMAN L8ECH0_HUMAN
# 45969               PLXA3_HUMAN L8ECH0_HUMAN
# 45970               PLXA3_HUMAN L8ECH0_HUMAN
# 45971  CLIC2_HUMAN A6PVS0_HUMAN Q86YM0_HUMAN
# 45972  CLIC2_HUMAN A6PVS0_HUMAN Q86YM0_HUMAN
#
# [45973 rows x 7 columns]

# %%
result.to_csv('TM_gnomad+GN(final)_nonPatho_missense.txt', header=True, index=False, sep='\t', mode='a')
