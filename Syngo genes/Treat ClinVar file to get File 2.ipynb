# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np

# %%
# General function to open files
def open_df(file):
    df = pd.read_csv(file, delimiter = "\t")
    return(df)

# %% [markdown]
# # Pathogenic

# %% [markdown]
# # Frameshift

# %%
df_fs_p = open_df('Path_fs.txt')
df_fs_p = df_fs_p.drop_duplicates()
i=df_fs_p[df_fs_p['Name']=='Name']
#print(i)
df_fs_p = df_fs_p.drop(df_fs_p.index[1279])

df_fs_p
# Out:
#                                                  Name Gene(s)  \
# 0             NM_198576.4(AGRN):c.543dup (p.Val182fs)    AGRN
# 1             NM_198576.4(AGRN):c.667dup (p.Leu223fs)    AGRN
# 2         NM_198576.4(AGRN):c.902_912del (p.Arg301fs)    AGRN
# 3         NM_198576.4(AGRN):c.914_947del (p.Arg305fs)    AGRN
# 4       NM_198576.4(AGRN):c.1036_1039dup (p.Glu347fs)    AGRN
# ...                                               ...     ...
# 3856  NM_005629.4(SLC6A8):c.1260_1281del (p.Gly421fs)  SLC6A8
# 3857  NM_005629.4(SLC6A8):c.1290_1309del (p.Asp431fs)  SLC6A8
# 3858  NM_005629.4(SLC6A8):c.1429_1430del (p.Ser477fs)  SLC6A8
# 3859       NM_005629.4(SLC6A8):c.1551del (p.Trp518fs)  SLC6A8
# 3860       NM_005629.4(SLC6A8):c.1583del (p.Pro528fs)  SLC6A8
#
#               Protein change                        Condition(s)  \
# 0              V182fs, V77fs  Myasthenic syndrome, congenital, 8
# 1             L223fs, L118fs  Myasthenic syndrome, congenital, 8
# ...

# %%
# Select the Gene(s) and Protein change columns to convert it into an easly understandable dataframe
df2_fs_p = df_fs_p[["Gene(s)", "Condition(s)"]]
df2_fs_p = df2_fs_p.drop_duplicates()
df2_fs_p
# Out:
#      Gene(s)                                       Condition(s)
# 0       AGRN                 Myasthenic syndrome, congenital, 8
# 5       AGRN                     Congenital myasthenic syndrome
# 9      CNTN2              Epilepsy, familial adult myoclonic, 5
# 10     CRIPT  Short stature with microcephaly and distinctiv...
# 11     CRIPT  Short stature with microcephaly and distinctiv...
# ...      ...                                                ...
# 3844  SLC6A8                    Creatine transporter deficiency
# 3845  SLC6A8                                       not provided
# 3850  SLC6A8       not provided|Creatine transporter deficiency
# 3852  SLC6A8       Creatine transporter deficiency|not provided
# 3858  SLC6A8                            Intellectual disability
#
# [877 rows x 2 columns]

# %% [markdown]
# # Missense

# %%
df_ms_p = open_df('Path_ms.txt')
df_ms_p = df_ms_p.drop_duplicates()
i=df_ms_p[df_ms_p['Name']=='Name']
#print(i)
df_ms_p = df_ms_p.drop(df_ms_p.index[612])

df_ms_p
# Out:
#                                              Name Gene(s)  \
# 0        NM_198576.4(AGRN):c.314A>T (p.Asn105Ile)    AGRN
# 1      NM_198576.4(AGRN):c.4999G>A (p.Val1667Met)    AGRN
# 2      NM_198576.4(AGRN):c.5023G>A (p.Gly1675Ser)    AGRN
# 3      NM_198576.4(AGRN):c.5125G>C (p.Gly1709Arg)    AGRN
# 4      NM_198576.4(AGRN):c.5179G>T (p.Val1727Phe)    AGRN
# ...                                           ...     ...
# 2621  NM_005629.4(SLC6A8):c.1262G>A (p.Gly421Asp)  SLC6A8
# 2622  NM_005629.4(SLC6A8):c.1396G>A (p.Gly466Arg)  SLC6A8
# 2623  NM_005629.4(SLC6A8):c.1473C>G (p.Cys491Trp)  SLC6A8
# 2624  NM_005629.4(SLC6A8):c.1661C>T (p.Pro554Leu)  SLC6A8
# 2625  NM_005629.4(SLC6A8):c.1703C>A (p.Ser568Tyr)  SLC6A8
#
#            Protein change                                       Condition(s)  \
# 0                   N105I                     Congenital myasthenic syndrome
# 1          V1562M, V1667M                 Myasthenic syndrome, congenital, 8
# ...

# %%
# Select the Gene(s) and Protein change columns to convert it into an easly understandable dataframe
df2_ms_p = df_ms_p[["Gene(s)", "Condition(s)"]]
df2_ms_p = df2_ms_p.drop_duplicates()
df2_ms_p
# Out:
#      Gene(s)                                       Condition(s)
# 0       AGRN                     Congenital myasthenic syndrome
# 1       AGRN                 Myasthenic syndrome, congenital, 8
# 3       AGRN  Congenital myasthenic syndrome|Myasthenic synd...
# 4       AGRN  Myasthenic syndrome, congenital, 8|Congenital ...
# 5      CDC42  Inborn genetic diseases|Neurodevelopmental dis...
# ...      ...                                                ...
# 2613  SLC9A6                                       not provided
# 2614  SLC9A6                              Christianson syndrome
# 2616  SLC6A8                    Creatine transporter deficiency
# 2617  SLC6A8                                       not provided
# 2618  SLC6A8                                      not specified
#
# [1427 rows x 2 columns]

# %% [markdown]
# # Nonsense

# %%
df_ns_p = open_df('Path_ns.txt')
df_ns_p = df_ns_p.drop_duplicates()
i=df_ns_p[df_ns_p['Name']=='Name']
#print(i)
df_ns_p = df_ns_p.drop(df_ns_p.index[1113])

df_ns_p
# Out:
#                                              Name Gene(s)  \
# 0       NM_198576.4(AGRN):c.1057C>T (p.Gln353Ter)    AGRN
# 1       NM_198576.4(AGRN):c.1275C>G (p.Tyr425Ter)    AGRN
# 2       NM_198576.4(AGRN):c.1323G>A (p.Trp441Ter)    AGRN
# 3       NM_198576.4(AGRN):c.2002G>T (p.Glu668Ter)    AGRN
# 4       NM_198576.4(AGRN):c.2500C>T (p.Arg834Ter)    AGRN
# ...                                           ...     ...
# 2880  NM_005629.4(SLC6A8):c.1494C>G (p.Tyr498Ter)  SLC6A8
# 2881  NM_005629.4(SLC6A8):c.1540C>T (p.Arg514Ter)  SLC6A8
# 2882  NM_005629.4(SLC6A8):c.1626C>A (p.Tyr542Ter)  SLC6A8
# 2883  NM_005629.4(SLC6A8):c.1659C>G (p.Tyr553Ter)  SLC6A8
# 2884  NM_005629.4(SLC6A8):c.1668G>A (p.Trp556Ter)  SLC6A8
#
#            Protein change                                       Condition(s)  \
# 0            Q353*, Q248*  Myasthenic syndrome, congenital, 8|Congenital ...
# 1            Y320*, Y425*                 Myasthenic syndrome, congenital, 8
# ...

# %%
# Select the Gene(s) and Protein change columns to convert it into an easly understandable dataframe
df2_ns_p = df_ns_p[["Gene(s)", "Condition(s)"]]
df2_ns_p = df2_ns_p.drop_duplicates()
df2_ns_p
# Out:
#      Gene(s)                                       Condition(s)
# 0       AGRN  Myasthenic syndrome, congenital, 8|Congenital ...
# 1       AGRN                 Myasthenic syndrome, congenital, 8
# 2       AGRN                     Abnormality of the musculature
# 6      CNTN2              Epilepsy, familial adult myoclonic, 5
# 7     BCL11A                                       not provided
# ...      ...                                                ...
# 2868  SLC9A6                 Christianson syndrome|not provided
# 2869  SLC9A6                              Christianson syndrome
# 2871  SLC6A8                                       not provided
# 2872  SLC6A8                    Creatine transporter deficiency
# 2881  SLC6A8  Intellectual disability|Inborn genetic disease...
#
# [1003 rows x 2 columns]

# %% [markdown]
# # Splicesites

# %%
df_ss_p = open_df('Path_ss.txt')
df_ss_p = df_ss_p.drop_duplicates()
i=df_ss_p[df_ss_p['Name']=='Name']
#print(i)
df_ss_p = df_ss_p.drop(df_ss_p.index[413])

df_ss_p
# Out:
#                                                Name   Gene(s)  Protein change  \
# 0               NM_001162383.2(ARHGEF2):c.1545+1del   ARHGEF2             NaN
# 1     NM_022893.4(BCL11A):c.633_643del (p.Gly212fs)    BCL11A  G178fs, G212fs
# 2                    NM_022893.4(BCL11A):c.385+2T>C    BCL11A             NaN
# 3                     NM_022893.4(BCL11A):c.56-1G>C    BCL11A             NaN
# 4                  NM_001692.4(ATP6V1B1):c.175-1G>C  ATP6V1B1             NaN
# ...                                             ...       ...             ...
# 1163                NM_005629.4(SLC6A8):c.1016+2T>C    SLC6A8             NaN
# 1164                NM_005629.4(SLC6A8):c.1142-2A>C    SLC6A8             NaN
# 1165                NM_005629.4(SLC6A8):c.1254+1G>A    SLC6A8             NaN
# 1166                NM_005629.4(SLC6A8):c.1255-2A>G    SLC6A8             NaN
# 1167          NM_005629.4(SLC6A8):c.1393-12_1395del    SLC6A8             NaN
#
# ...

# %%
# Select the Gene(s) and Protein change columns to convert it into an easly understandable dataframe
df2_ss_p = df_ss_p[["Gene(s)", "Condition(s)"]]
df2_ss_p = df2_ss_p.drop_duplicates()
df2_ss_p
# Out:
#        Gene(s)                                       Condition(s)
# 0      ARHGEF2  Neurodevelopmental disorder with midbrain and ...
# 1       BCL11A                                       not provided
# 2       BCL11A  Intellectual developmental disorder with persi...
# 3       BCL11A                            Inborn genetic diseases
# 4     ATP6V1B1  not provided|Postaxial polydactyly type A1|Nep...
# ...        ...                                                ...
# 1159    SLC9A6                              Christianson syndrome
# 1160    SLC6A8                    Creatine transporter deficiency
# 1161    SLC6A8                                       not provided
# 1162    SLC6A8                            Intellectual disability
# 1163    SLC6A8  Inborn genetic diseases|Creatine transporter d...
#
# [513 rows x 2 columns]

# %% [markdown]
# # Likely Pathogenic

# %% [markdown]
# # Frameshift

# %%
df_fs_lp = open_df('Likely_fs.txt')
df_fs_lp = df_fs_lp.drop_duplicates()
i=df_fs_lp[df_fs_lp['Name']=='Name']
#print(i)
df_fs_lp = df_fs_lp.drop(df_fs_lp.index[207])

df_fs_lp
# Out:
#                                                   Name Gene(s)  \
# 0          NM_198576.4(AGRN):c.574_578dup (p.Ser194fs)    AGRN
# 1            NM_198576.4(AGRN):c.4922dup (p.Asn1641fs)    AGRN
# 2            NM_198576.4(AGRN):c.5312dup (p.Ser1772fs)    AGRN
# 3        NM_004304.5(ALK):c.4298_4299del (p.Glu1433fs)     ALK
# 4           NM_022893.4(BCL11A):c.2194dup (p.Arg732fs)  BCL11A
# ..                                                 ...     ...
# 775  NM_001379110.1(SLC9A6):c.1143_1144del (p.Phe38...  SLC9A6
# 776  NM_001379110.1(SLC9A6):c.1423_1424insCA (p.Gly...  SLC9A6
# 777      NM_005629.4(SLC6A8):c.918_919del (p.Trp306fs)  SLC6A8
# 778          NM_005629.4(SLC6A8):c.946dup (p.Ser316fs)  SLC6A8
# 779    NM_005629.4(SLC6A8):c.1289_1299del (p.Leu430fs)  SLC6A8
#
#                      Protein change  \
# 0                     S194fs, S89fs
# 1                  N1536fs, N1641fs
# 2         S1772fs, S1671fs, S1776fs
# 3                   E1433fs, E365fs
# ...

# %%
# Select the Gene(s) and Protein change columns to convert it into an easly understandable dataframe
df2_fs_lp = df_fs_lp[["Gene(s)", "Condition(s)"]]
df2_fs_lp = df2_fs_lp.drop_duplicates()
df2_fs_lp
# Out:
#     Gene(s)                                       Condition(s)
# 0      AGRN                     Congenital myasthenic syndrome
# 1      AGRN  Myasthenic syndrome, congenital, 8, with pre- ...
# 2      AGRN                                       not provided
# 3       ALK                                   Rhabdomyosarcoma
# 4    BCL11A                            Inborn genetic diseases
# ..      ...                                                ...
# 769    SYN1  Epilepsy, X-linked, with variable learning dis...
# 774     SYP                                       not provided
# 775  SLC9A6  not provided|Scoliosis|Global developmental de...
# 776  SLC9A6                              Christianson syndrome
# 777  SLC6A8                                       not provided
#
# [443 rows x 2 columns]

# %% [markdown]
# # Missense

# %%
df_ms_lp = open_df('Likely_ms.txt')
df_ms_lp = df_ms_lp.drop_duplicates()
i=df_ms_lp[df_ms_lp['Name']=='Name']
#print(i)
df_ms_lp = df_ms_lp.drop(df_ms_lp.index[589])

df_ms_lp
# Out:
#                                              Name Gene(s)  \
# 0         NM_198576.4(AGRN):c.226G>A (p.Gly76Ser)    AGRN
# 1      NM_198576.4(AGRN):c.5276T>C (p.Leu1759Pro)    AGRN
# 2         NM_001791.4(CDC42):c.62T>C (p.Ile21Thr)   CDC42
# 3         NM_001791.4(CDC42):c.67T>A (p.Tyr23Asn)   CDC42
# 4         NM_001791.4(CDC42):c.68A>G (p.Tyr23Cys)   CDC42
# ...                                           ...     ...
# 2939   NM_005629.4(SLC6A8):c.912G>C (p.Gln304His)  SLC6A8
# 2940  NM_005629.4(SLC6A8):c.1208C>T (p.Ala403Val)  SLC6A8
# 2941  NM_005629.4(SLC6A8):c.1250G>A (p.Ser417Asn)  SLC6A8
# 2942  NM_005629.4(SLC6A8):c.1252C>A (p.Gln418Lys)  SLC6A8
# 2943  NM_005629.4(SLC6A8):c.1631C>T (p.Pro544Leu)  SLC6A8
#
#               Protein change  \
# 0                       G76S
# 1     L1759P, L1658P, L1763P
# 2                       I21T
# 3                       Y23N
# 4                       Y23C
# ...                      ...
# 2939            Q304H, Q189H
# ...

# %%
# Select the Gene(s) and Protein change columns to convert it into an easly understandable dataframe
df2_ms_lp = df_ms_lp[["Gene(s)", "Condition(s)"]]
df2_ms_lp = df2_ms_lp.drop_duplicates()
df2_ms_lp
# Out:
#      Gene(s)                                       Condition(s)
# 0       AGRN  Myasthenic syndrome, congenital, 8|Congenital ...
# 1       AGRN                 Myasthenic syndrome, congenital, 8
# 2      CDC42  Takenouchi-Kosaki syndrome|not provided|Abnorm...
# 3      CDC42                                       not provided
# 4      CDC42  Inborn genetic diseases|Neurodevelopmental dis...
# ...      ...                                                ...
# 2937  SLC6A8       not provided|Creatine transporter deficiency
# 2938  SLC6A8                    Creatine transporter deficiency
# 2939  SLC6A8                                       not provided
# 2940  SLC6A8  Intellectual disability|Abnormal facial shape|...
# 2942  SLC6A8                        Neurodevelopmental disorder
#
# [1380 rows x 2 columns]

# %% [markdown]
# # Nonsense

# %%
df_ns_lp = open_df('Likely_ns.txt')
df_ns_lp = df_ns_lp.drop_duplicates()
i=df_ns_lp[df_ns_lp['Name']=='Name']
#print(i)
df_ns_lp = df_ns_lp.drop(df_ns_lp.index[196])

df_ns_lp
# Out:
#                                                 Name   Gene(s)  \
# 0         NM_198576.4(AGRN):c.4621C>T (p.Arg1541Ter)      AGRN
# 1        NM_022893.4(BCL11A):c.1755C>A (p.Cys585Ter)    BCL11A
# 2          NM_022893.4(BCL11A):c.193G>T (p.Glu65Ter)    BCL11A
# 3          NM_022893.4(BCL11A):c.154C>T (p.Gln52Ter)    BCL11A
# 4         NM_001692.4(ATP6V1B1):c.79C>T (p.Gln27Ter)  ATP6V1B1
# ..                                               ...       ...
# 641  NM_001372044.2(SHANK3):c.4732C>T (p.Gln1578Ter)    SHANK3
# 642     NM_033517.1(SHANK3):c.4861A>T (p.Lys1621Ter)    SHANK3
# 643  NM_001372044.2(SHANK3):c.5197C>T (p.Arg1733Ter)    SHANK3
# 644         NM_006950.3(SYN1):c.745C>T (p.Gln249Ter)      SYN1
# 645         NM_006950.3(SYN1):c.361G>T (p.Glu121Ter)      SYN1
#
#      Protein change                                       Condition(s)  \
# 0    R1541*, R1436*                                       not provided
# ...

# %%
# Select the Gene(s) and Protein change columns to convert it into an easly understandable dataframe
df2_ns_lp = df_ns_lp[["Gene(s)", "Condition(s)"]]
df2_ns_lp = df2_ns_lp.drop_duplicates()
df2_ns_lp
# Out:
#       Gene(s)                                       Condition(s)
# 0        AGRN                                       not provided
# 1      BCL11A  Intellectual developmental disorder with persi...
# 2      BCL11A  Marfanoid habitus and intellectual disability|...
# 4    ATP6V1B1                             Renal tubular acidosis
# 5    ATP6V1B1  Renal tubular acidosis with progressive nerve ...
# ..        ...                                                ...
# 640    SHANK3               not provided|Inborn genetic diseases
# 641    SHANK3                          22q13.3 deletion syndrome
# 642    SHANK3                                       not provided
# 644      SYN1                            Intellectual disability
# 645      SYN1                                       not provided
#
# [390 rows x 2 columns]

# %% [markdown]
# # Splicesites

# %%
df_ss_lp = open_df('Likely_ss.txt')
df_ss_lp = df_ss_lp.drop_duplicates()
i=df_ss_lp[df_ss_lp['Name']=='Name']
#print(i)
df_ss_lp = df_ss_lp.drop(df_ss_lp.index[264])

df_ss_lp
# Out:
#                                       Name Gene(s) Protein change  \
# 0    NM_198576.4(AGRN):c.1177+4_1177+50del    AGRN            NaN
# 1      NM_198576.4(AGRN):c.4745-47_4753del    AGRN            NaN
# 2           NM_005076.5(CNTN2):c.1241-1G>C   CNTN2            NaN
# 3           NM_005076.5(CNTN2):c.2432-2A>G   CNTN2            NaN
# 4           NM_005076.5(CNTN2):c.2731+1G>A   CNTN2            NaN
# ..                                     ...     ...            ...
# 823      NM_001379110.1(SLC9A6):c.743+1G>A  SLC9A6            NaN
# 824     NM_001379110.1(SLC9A6):c.1661+1G>A  SLC9A6            NaN
# 825   NM_005629.4(SLC6A8):c.644+3_644+6del  SLC6A8            NaN
# 826         NM_005629.4(SLC6A8):c.912+2T>G  SLC6A8            NaN
# 827  NM_005629.4(SLC6A8):c.1255-35_1272del  SLC6A8            NaN
#
#                                           Condition(s)  \
# 0                   Myasthenic syndrome, congenital, 8
# 1                   Myasthenic syndrome, congenital, 8
# ...

# %%
# Select the Gene(s) and Protein change columns to convert it into an easly understandable dataframe
df2_ss_lp = df_ss_lp[["Gene(s)", "Condition(s)"]]
#df2_ss_lp = df2_ss_lp.groupby(['Gene(s)', 'Condition(s)']).first()
df2_ss_lp = df2_ss_lp.drop_duplicates()
df2_ss_lp
# Out:
#     Gene(s)                                       Condition(s)
# 0      AGRN                 Myasthenic syndrome, congenital, 8
# 2     CNTN2  Epilepsy, familial adult myoclonic, 5|not prov...
# 3     CNTN2                                       not provided
# 4     CNTN2              Epilepsy, familial adult myoclonic, 5
# 5    BCL11A                                       not provided
# ..      ...                                                ...
# 821    SYN1  Epilepsy, X-linked, with variable learning dis...
# 822  SLC9A6                                       not provided
# 823  SLC9A6                 not provided|Christianson syndrome
# 825  SLC6A8                                       not provided
# 826  SLC6A8                    Creatine transporter deficiency
#
# [407 rows x 2 columns]

# %%
df_final = pd.concat([df2_fs_p, df2_ms_p, df2_ns_p, df2_ss_p, df2_fs_lp, df2_ms_lp, df2_ns_lp, df2_ss_lp])
df_final = df_final.groupby(['Gene(s)'])['Condition(s)'].agg([('Condition(s)', ', '.join)]).reset_index()
df_final
# Out:
#            Gene(s)                                       Condition(s)
# 0             ABL1  Congenital heart defects and skeletal malforma...
# 1      ACADVL|DLG4  Abnormality of circulating enzyme level|Rhabdo...
# 2             ACAN  Osteochondritis dissecans, not provided, not p...
# 3    ACTC1|GJD2-DT  Atrial septal defect 5, Dilated cardiomyopathy...
# 4            ACTG1  Deafness, autosomal dominant 20, Baraitser-Win...
# ..             ...                                                ...
# 503           WNK1  Hereditary sensory and autonomic neuropathy ty...
# 504          WNT5A  Robinow syndrome, autosomal dominant 1, Robino...
# 505          WNT7A  Schinzel phocomelia syndrome, Schinzel phocome...
# 506    YARS2|DNM1L  Encephalopathy due to defective mitochondrial ...
# 507          YWHAG  Generalized tonic-clonic seizures|Specific lea...
#
# [508 rows x 2 columns]

# %%
df_final.to_csv('File_clinical_significance(ClinVar).txt', header=True, index=None, sep=' ', mode='a')
